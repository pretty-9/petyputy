# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tag import pos_tag
import string


nltk.download('punkt')
nltk.download('punkt_tab')  
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng') 


text = """
Artificial Intelligence is transforming the world.
Artificial Intelligence helps in healthcare, education,
robotics, and many smart applications.
"""

print("Original Text:")
print(text)



print("\n1. Tokenized Words:")
print(tokens)


words = [
    word.lower()
    for word in tokens
    if word not in string.punctuation
]

freq = FreqDist(words)

print("\n2. Word Frequency:")
for word, count in freq.items():
    print(f"{word}: {count}")


stop_words = set(stopwords.words('english'))

filtered_words = [
    word for word in words
    if word not in stop_words
]

print("\n3. Words After Removing Stop Words:")
print(filtered_words)

pos_tags = pos_tag(filtered_words)

print("\n4. POS Tagging:")
for word, tag in pos_tags:
    print(f"{word:15} -> {tag}")


print("\n5. Top 5 Most Frequent Words:")
for word, count in freq.most_common(5):
    print(f"{word}: {count}")
# Out:
# Original Text:
#
# Artificial Intelligence is transforming the world.
# Artificial Intelligence helps in healthcare, education,
# robotics, and many smart applications.
#
#
# 1. Tokenized Words:
# ['Artificial', 'Intelligence', 'is', 'transforming', 'the', 'world', '.', 'Artificial', 'Intelligence', 'helps', 'in', 'healthcare', ',', 'education', ',', 'robotics', ',', 'and', 'many', 'smart', 'applications', '.']
#
# 2. Word Frequency:
# artificial: 2
# intelligence: 2
# is: 1
# transforming: 1
# the: 1
# world: 1
# helps: 1
# in: 1
# healthcare: 1
# education: 1
# robotics: 1
# and: 1
# many: 1
# smart: 1
# applications: 1
#
# 3. Words After Removing Stop Words:
# ['artificial', 'intelligence', 'transforming', 'world', 'artificial', 'intelligence', 'helps', 'healthcare', 'education', 'robotics', 'many', 'smart', 'applications']
#
# 4. POS Tagging:
# artificial      -> JJ
# intelligence    -> NN
# transforming    -> VBG
# world           -> NN
# artificial      -> JJ
# intelligence    -> NN
# helps           -> VBZ
# healthcare      -> VB
# education       -> NN
# robotics        -> NNS
# many            -> JJ
# smart           -> JJ
# applications    -> NNS
#
# 5. Top 5 Most Frequent Words:
# artificial: 2
# intelligence: 2
# is: 1
# transforming: 1
# the: 1
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shivambhagat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/shivambhagat/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shivambhagat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/shivambhagat/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/shivambhagat/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
